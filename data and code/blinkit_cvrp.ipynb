# %%
from pulp import LpProblem, LpVariable, lpSum, LpMinimize

# Define parameters
MaxBatchSize = 10
MaxBatchTime = 15  # in minutes
OrderTimeWindow = 10  # in minutes
alpha = 0.75  # weight for emissions
beta = 0.25  # weight for batching

# Sample data (you should replace this with your actual data)
customers = [1, 2, 3, 4, 5]
demands = {1: 1, 2: 2, 3: 1, 4: 3, 5: 2}
travel_time = {(i, j): 10 for i in customers for j in customers if i != j}
emission_factor = {(i, j): 0.1 for i in customers for j in customers if i != j}

# Set an arbitrary value for the emission constraint (you should replace this with your actual data)
Emax = 10

# Create LP problem for determining the optimum batch size
batch_size_prob = LpProblem("Optimal_Batch_Size", LpMinimize)

# Decision variables
x = LpVariable.dicts("x", [(i, j) for i in customers for j in customers if i != j], cat="Binary")
y = LpVariable.dicts("y", customers, cat="Binary")
BatchSize = LpVariable("BatchSize", lowBound=1, upBound=MaxBatchSize, cat="Continuous")
u = LpVariable.dicts("u", customers, lowBound=0, upBound=MaxBatchSize, cat="Continuous")

# Objective function
batch_size_prob += (
    lpSum(travel_time[i, j] * x[i, j] for i in customers for j in customers if i != j) +
    alpha * lpSum(emission_factor[i, j] * demands[i] * x[i, j] for i in customers for j in customers if i != j) +
    beta * BatchSize
)

# Max weight per batch
MaxWeightPerBatch = 50

# Constraints
batch_size_prob += lpSum(y[i] * demands[i] for i in customers) <= MaxWeightPerBatch  # Batch weight constraint
batch_size_prob += lpSum(travel_time[i, j] * x[i, j] for i in customers for j in customers if i != j) <= MaxBatchTime  # Batch time constraint
batch_size_prob += lpSum(emission_factor[i, j] * demands[i] * x[i, j] for i in customers for j in customers if i != j) <= Emax  # Emission constraint

# Position assignment for customers in a batch
for i in customers:
    for j in customers:
        if i != j:
            batch_size_prob += u[i] - u[j] + MaxBatchSize * x[i, j] <= MaxBatchSize - 1  # Position assignment for customers in a batch

            # Ensure that a batch is selected only if any customer in that batch is selected
            batch_size_prob += BatchSize >= y[i]
# Solve the problem
batch_size_prob.solve()

# Print results
print("Status:", batch_size_prob.status)
print("Optimal Batch Size:", round(BatchSize.varValue, 2))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/0f8a9956d3454fadab61c49b69d37574-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/0f8a9956d3454fadab61c49b69d37574-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 48 COLUMNS
# At line 265 RHS
# At line 309 BOUNDS
# At line 342 ENDATA
# Problem MODEL has 43 rows, 31 columns and 145 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.25 - 0.00 seconds
# Cgl0004I processed model has 20 rows, 5 columns (0 integer (0 of which binary)) and 40 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0.25 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.25000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Status: 1
# Optimal Batch Size: 1.0

# %%
import random
from pulp import LpProblem, LpVariable, lpSum, LpMinimize

# Simulated data
random.seed(5)  # For reproducibility

# Constants
OrderTimeWindow = 10  # in minutes
alpha = 1  # weight for emissions
beta = 1  # weight for batching

# Simulated traffic speeds (km/h)
best_case_speed_range = (40, 50)
average_speed = 45
low_speed= (1,40)
high=(51,80)

# Assuming you have a function to calculate travel time based on distance and speed
def calculate_travel_time(customer1, customer2, speed):
    # Your logic to calculate travel time based on distance and speed
    distance = ((customer1["x"] - customer2["x"])**2 + (customer1["y"] - customer2["y"])**2)**0.5
    return distance / speed

# Generate random orders with coordinates
def generate_orders(num_orders):
    orders = []
    for _ in range(num_orders):
        order = {
            "customer_id": random.randint(1, 100),
            "order_weight": random.uniform(1, 5),  # Weight in kg
            "x": random.uniform(0, 100),  # X-coordinate
            "y": random.uniform(0, 100),  # Y-coordinate
        }
        orders.append(order)
    return orders

# Traffic scenarios
def simulate_traffic_scenario(speed_range):
    best_case_speed = random.uniform(speed_range[0], speed_range[1])
    print(f"\nSimulating best-case traffic scenario with speed: {best_case_speed} km/h...")

    total_delivery_cost = 0
    total_emissions = 0

    for iteration in range(1, 31):
        print(f"\nIteration {iteration}")

        # Generate random orders with coordinates for each iteration
        orders = generate_orders(200)

        # Create LP problem for determining the optimal batch size
        batch_size_prob = LpProblem(f"Optimal_Batch_Size_Best_Case_Iteration_{iteration}", LpMinimize)

        # Dynamic constraints
        MaxVehicleCapacity = 40  # Example: Maximum capacity of a delivery vehicle in terms of order weight
        MaxOperationTime = 180  # Example: Maximum time for a delivery operation in minutes

        # Decision variables
        x = LpVariable.dicts("x", [(i["customer_id"], j["customer_id"]) for i in orders for j in orders if i != j], cat="Binary")
        y = LpVariable.dicts("y", [i["customer_id"] for i in orders], cat="Binary")
        BatchSize = LpVariable("BatchSize", lowBound=1, upBound=MaxVehicleCapacity, cat="Continuous")
        u = LpVariable.dicts("u", [i["customer_id"] for i in orders], lowBound=0, upBound=MaxVehicleCapacity, cat="Continuous")

        # Objective function
        batch_size_prob += (
            lpSum((i["order_weight"] + j["order_weight"]) * x[i["customer_id"], j["customer_id"]] for i in orders for j in orders if i != j) +
            alpha * lpSum(i["order_weight"] * x[i["customer_id"], j["customer_id"]] for i in orders for j in orders if i != j) +
            beta * BatchSize
        )

        # Constraints
        batch_size_prob += lpSum(y[i["customer_id"]] for i in orders) <= BatchSize  # Batch size constraint
        batch_size_prob += lpSum(calculate_travel_time(i, j, best_case_speed) * x[i["customer_id"], j["customer_id"]] for i in orders for j in orders if i != j) <= MaxOperationTime  # Batch time constraint

        # Solve the problem
        batch_size_prob.solve()

        # Calculate metrics
        total_delivery_cost += batch_size_prob.objective.value()
        total_emissions += alpha * batch_size_prob.objective.value()

        # Print results for each iteration
        print("Status:", batch_size_prob.status)
        print("Optimal Batch Size:", round(BatchSize.varValue, 2))
        print("Total Delivery Cost:", round(batch_size_prob.objective.value(), 2))
        print("Total Emissions:", round(alpha * batch_size_prob.objective.value(), 2))

    # Print average results for the best-case scenario
    avg_delivery_cost = total_delivery_cost / 30
    avg_emissions = total_emissions / 30
    print(f"\nAverage Delivery Cost (Best Case): {round(avg_delivery_cost, 2)}")
    print(f"Average Emissions (Best Case): {round(avg_emissions, 2)}")

# Run simulation for the best-case traffic scenario
simulate_traffic_scenario(best_case_speed_range)

# Run simulation for the best-case traffic scenario
simulate_traffic_scenario(low_speed)

# Run simulation for the best-case traffic scenario
simulate_traffic_scenario(high)
# Out:
# Simulating best-case traffic scenario with speed: 46.22901694889702 km/h...
#
# Iteration 1
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/a9ab15b636c74725b8c4df873df4eed8-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/a9ab15b636c74725b8c4df873df4eed8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 30431 RHS
# At line 30434 BOUNDS
# At line 38064 ENDATA
# Problem MODEL has 2 rows, 7628 columns and 7628 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 2
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/479d45862a6d44faaa8dcbe93bb21ae3-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/479d45862a6d44faaa8dcbe93bb21ae3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 30455 RHS
# At line 30458 BOUNDS
# At line 38094 ENDATA
# Problem MODEL has 2 rows, 7634 columns and 7634 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 3
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/d98544bcd4e942bcbab468cdf5624efc-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/d98544bcd4e942bcbab468cdf5624efc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 31853 RHS
# At line 31856 BOUNDS
# At line 39842 ENDATA
# Problem MODEL has 2 rows, 7984 columns and 7984 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 4
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/8a4ea13bb16343a5a91f74200788a276-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/8a4ea13bb16343a5a91f74200788a276-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29728 RHS
# At line 29731 BOUNDS
# At line 37185 ENDATA
# Problem MODEL has 2 rows, 7452 columns and 7452 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 5
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/6252f3ca66f44687a58d649906f4c03e-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/6252f3ca66f44687a58d649906f4c03e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 26409 RHS
# At line 26412 BOUNDS
# At line 33035 ENDATA
# Problem MODEL has 2 rows, 6621 columns and 6621 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 6
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/0808299a80814e44ba7ffa136a7a6169-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/0808299a80814e44ba7ffa136a7a6169-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29744 RHS
# At line 29747 BOUNDS
# At line 37205 ENDATA
# Problem MODEL has 2 rows, 7456 columns and 7456 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 7
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/a02ca20763f94159bb4757be49b967f7-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/a02ca20763f94159bb4757be49b967f7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 25750 RHS
# At line 25753 BOUNDS
# At line 32211 ENDATA
# Problem MODEL has 2 rows, 6456 columns and 6456 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 8
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/80c3b036fe654642baf39b02f28bdd39-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/80c3b036fe654642baf39b02f28bdd39-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 34753 RHS
# At line 34756 BOUNDS
# At line 43468 ENDATA
# Problem MODEL has 2 rows, 8710 columns and 8710 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 9
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/5e37ca864d5c4c6b899459b9789ffad8-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/5e37ca864d5c4c6b899459b9789ffad8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 27707 RHS
# At line 27710 BOUNDS
# At line 34658 ENDATA
# Problem MODEL has 2 rows, 6946 columns and 6946 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 10
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/d1ca2839fd7841d091b6b0d095bf51eb-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/d1ca2839fd7841d091b6b0d095bf51eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 27727 RHS
# At line 27730 BOUNDS
# At line 34683 ENDATA
# Problem MODEL has 2 rows, 6951 columns and 6951 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 11
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/1e354cd40b7a4027bf0683b8434b7e1c-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/1e354cd40b7a4027bf0683b8434b7e1c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 31122 RHS
# At line 31125 BOUNDS
# At line 38928 ENDATA
# Problem MODEL has 2 rows, 7801 columns and 7801 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 12
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/44f537d115084fec86abe71570d619e3-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/44f537d115084fec86abe71570d619e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29065 RHS
# At line 29068 BOUNDS
# At line 36356 ENDATA
# Problem MODEL has 2 rows, 7286 columns and 7286 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 13
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/fa864d90b6124e43a9a4d3ebdae689d2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/fa864d90b6124e43a9a4d3ebdae689d2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 30435 RHS
# At line 30438 BOUNDS
# At line 38069 ENDATA
# Problem MODEL has 2 rows, 7629 columns and 7629 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 14
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/6303f737a39e4caa8bd90c0c0090dcfb-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/6303f737a39e4caa8bd90c0c0090dcfb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 27715 RHS
# At line 27718 BOUNDS
# At line 34668 ENDATA
# Problem MODEL has 2 rows, 6948 columns and 6948 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 15
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/4db420919ad447d0984e51609d617dad-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/4db420919ad447d0984e51609d617dad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 32564 RHS
# At line 32567 BOUNDS
# At line 40731 ENDATA
# Problem MODEL has 2 rows, 8162 columns and 8162 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 16
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/7079d94160b74f20a0ca0e4fa3630628-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/7079d94160b74f20a0ca0e4fa3630628-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 31849 RHS
# At line 31852 BOUNDS
# At line 39837 ENDATA
# Problem MODEL has 2 rows, 7983 columns and 7983 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 17
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/71ef8795c1c64b00a276345db5b931da-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/71ef8795c1c64b00a276345db5b931da-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 27715 RHS
# At line 27718 BOUNDS
# At line 34668 ENDATA
# Problem MODEL has 2 rows, 6948 columns and 6948 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 18
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/84146f487aaf4456b201756a8333a82a-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/84146f487aaf4456b201756a8333a82a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29061 RHS
# At line 29064 BOUNDS
# At line 36351 ENDATA
# Problem MODEL has 2 rows, 7285 columns and 7285 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 19
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/4c79a8e72dcc4ec28104401b74fc331a-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/4c79a8e72dcc4ec28104401b74fc331a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 26409 RHS
# At line 26412 BOUNDS
# At line 33035 ENDATA
# Problem MODEL has 2 rows, 6621 columns and 6621 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 20
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/a4345771f4da402387855dc64caedc4b-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/a4345771f4da402387855dc64caedc4b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29061 RHS
# At line 29064 BOUNDS
# At line 36351 ENDATA
# Problem MODEL has 2 rows, 7285 columns and 7285 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 21
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/8ddc4bae4b114b9eb5b4f055714d84a2-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/8ddc4bae4b114b9eb5b4f055714d84a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 30423 RHS
# At line 30426 BOUNDS
# At line 38054 ENDATA
# Problem MODEL has 2 rows, 7626 columns and 7626 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 27699 RHS
# At line 27702 BOUNDS
# At line 34648 ENDATA
# Problem MODEL has 2 rows, 6944 columns and 6944 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 25
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/3b4e23db87b1402cb0705d1fd45b98ce-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/3b4e23db87b1402cb0705d1fd45b98ce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 30443 RHS
# At line 30446 BOUNDS
# At line 38079 ENDATA
# Problem MODEL has 2 rows, 7631 columns and 7631 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 26
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/d6420450adf547ebac38104b8734198b-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/d6420450adf547ebac38104b8734198b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 28370 RHS
# At line 28373 BOUNDS
# At line 35487 ENDATA
# Problem MODEL has 2 rows, 7112 columns and 7112 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 27
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/533b4c22b2224b48ab80080465909f63-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/533b4c22b2224b48ab80080465909f63-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29073 RHS
# At line 29076 BOUNDS
# At line 36366 ENDATA
# Problem MODEL has 2 rows, 7288 columns and 7288 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 28
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/9cfaa9d5ecac4df191e0bd4b40333a47-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/9cfaa9d5ecac4df191e0bd4b40333a47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29756 RHS
# At line 29759 BOUNDS
# At line 37220 ENDATA
# Problem MODEL has 2 rows, 7459 columns and 7459 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 29
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/6db4fb09f5884a368918879a8dbd3d31-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/6db4fb09f5884a368918879a8dbd3d31-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29061 RHS
# At line 29064 BOUNDS
# At line 36351 ENDATA
# Problem MODEL has 2 rows, 7285 columns and 7285 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Iteration 30
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/amarigarrett/opt/anaconda3/lib/python3.9/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/9e801f6b3fee471f91ea948c1c3fb2d3-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/lt/njk9c7vd43n4xfmcy1kt75c40000gn/T/9e801f6b3fee471f91ea948c1c3fb2d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7 COLUMNS
# At line 29740 RHS
# At line 29743 BOUNDS
# At line 37200 ENDATA
# Problem MODEL has 2 rows, 7455 columns and 7455 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 1 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 1 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.04
#
# Status: 1
# Optimal Batch Size: 1.0
# Total Delivery Cost: 1.0
# Total Emissions: 1.0
#
# Average Delivery Cost (Best Case): 1.0
# Average Emissions (Best Case): 1.0
